# %% [markdown]
# Listas:

# %%
stringList = ["guilherme", "Teles", "Vithor"]

objList = [{
    "name": "guilherme"
}]

print(stringList)
# Out:
# ['guilherme', 'Teles', 'Vithor']

# %% [markdown]
# Tuplas:

# %%
stringTuple = ("apple", "banana", "cherry")
print(stringTuple)

print("-----------------------------")
print("-----------------------------")

intTuple = (1,2,3)

print(intTuple)
# Out:
# ('apple', 'banana', 'cherry')
# -----------------------------
# -----------------------------
# (1, 2, 3)
